# %% [markdown]
# # Table of Contents
#
# ### Contents:
# - [Imports, reading in data](#Initial-Steps)
# - [Choosing features](#Choosing-features)
# - [Fitting the model](#Fitting-the-model)
# - [Scoring and evaluating the model](#Scoring-and-evaluating-the-model)

# %% [markdown]
# This model is going to take into account only columns related to location

# %% [markdown]
# # Initial Steps

# %%
# imports

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %matplotlib inline
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# read in cleaned TRAIN data
train = pd.read_csv('../datasets/train_clean_dum.csv')

# %%
train.shape
# Out:
# (1556, 247)

# %%
# I want to play with the training data, I don't actually want to mess with it
# rerun this cell to get original data
df = train

# %%
# read in cleaned TEST data
test = pd.read_csv('../datasets/test_clean_dum.csv')

# %%
test.shape
# Out:
# (878, 246)

# %% [markdown]
# #### * note that the baseline model is the mean house price, done in april 2 notebook

# %% [markdown]
# # Choosing features

# %% [markdown]
# #### By inspection, I decided that these were the columns most related to location:
#
# - MS Zoning
# - Neighborhood
# - Condition 1
# - Condition 2

# %%
features =[]
for name in train.columns:
    if 'ms_zoning' in name:
        features.append(name)
    elif 'neighborhood' in name:
        features.append(name)
    elif 'condition' in name:
        features.append(name)

# %%
features
# Out:
# ['ms_zoning_FV',
#  'ms_zoning_I (all)',
#  'ms_zoning_RH',
#  'ms_zoning_RL',
#  'ms_zoning_RM',
#  'neighborhood_Blueste',
#  'neighborhood_BrDale',
#  'neighborhood_BrkSide',
#  'neighborhood_ClearCr',
#  'neighborhood_CollgCr',
#  'neighborhood_Crawfor',
#  'neighborhood_Edwards',
#  'neighborhood_Gilbert',
#  'neighborhood_Greens',
#  'neighborhood_IDOTRR',
#  'neighborhood_MeadowV',
#  'neighborhood_Mitchel',
#  'neighborhood_NAmes',
#  'neighborhood_NPkVill',
#  'neighborhood_NWAmes',
#  'neighborhood_NoRidge',
#  'neighborhood_NridgHt',
#  'neighborhood_OldTown',
#  'neighborhood_SWISU',
#  'neighborhood_Sawyer',
#  'neighborhood_SawyerW',
#  'neighborhood_Somerst',
#  'neighborhood_StoneBr',
#  'neighborhood_Timber',
#  'neighborhood_Veenker',
#  'condition_1_Feedr',
#  'condition_1_Norm',
#  'condition_1_PosA',
#  'condition_1_PosN',
#  'condition_1_RRAe',
#  'condition_1_RRAn',
#  'condition_1_RRNe',
#  'condition_1_RRNn',
#  'condition_2_Feedr',
#  'condition_2_Norm',
#  'condition_2_PosA',
#  'condition_2_PosN',
#  'condition_2_RRNn']

# %%
# let's look at the pairplots of the columns of interest against saleprice
sns.pairplot(df, y_vars=features, x_vars=['saleprice'])

# looks like a lot of the variables would do well with logistic regression instead

# %%
# let X be the numeric columns most strongly correlated to sale price
X = df[features]

# let y be the sale price, the goal output
y = df['saleprice']

# %%
# save a copy of the official TEST dataset that has these same columns
test_mod_3 = test[features]
test_mod_3.to_csv('../datasets/test_mod_2.csv')

# %% [markdown]
# # Fitting the model

# %%
# split our data into train and test data to properly cross validate our model 

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 5)

# %%
# instantiate linear regression model and fit it to our data

lr = LinearRegression()
lr.fit(X_train, y_train)

# look at the coefficients and interpret them
pd.Series(lr.coef_, index = features)
# Out:
# ms_zoning_FV            1.010505e+04
# ms_zoning_I (all)      -3.186869e-09
# ms_zoning_RH            1.412964e+04
# ms_zoning_RL            2.756562e+04
# ms_zoning_RM            4.100751e+04
# neighborhood_Blueste   -5.760508e+04
# neighborhood_BrDale    -9.849133e+04
# neighborhood_BrkSide   -5.949665e+04
# neighborhood_ClearCr    3.673180e+04
# neighborhood_CollgCr    8.060554e+03
# neighborhood_Crawfor    1.314769e+04
# neighborhood_Edwards   -4.782022e+04
# neighborhood_Gilbert    3.476514e+03
# neighborhood_Greens     3.523467e+03
# neighborhood_IDOTRR    -7.652865e+04
# neighborhood_MeadowV   -8.639619e+04
# neighborhood_Mitchel   -1.783282e+04
# neighborhood_NAmes     -3.530087e+04
# neighborhood_NPkVill   -4.328935e+04
# neighborhood_NWAmes    -2.616787e+03
# neighborhood_NoRidge    1.292385e+05
# neighborhood_NridgHt    1.377168e+05
# neighborhood_OldTown   -6.595024e+04
# neighborhood_SWISU     -4.210847e+04
# neighborhood_Sawyer    -4.094381e+04
# neighborhood_SawyerW    1.157273e+04
# neighborhood_Somerst    5.864537e+04
# neighborhood_StoneBr    1.622854e+05
# neighborhood_Timber     5.690299e+04
# neighborhood_Veenker    8.020611e+04
# condition_1_Feedr       5.345175e+02
# condition_1_Norm        1.335570e+04
# condition_1_PosA        5.330424e+04
# condition_1_PosN        7.257687e+04
# condition_1_RRAe       -7.626234e+03
# condition_1_RRAn        1.823799e+04
# condition_1_RRNe        3.815632e+04
# condition_1_RRNn       -2.006618e+03
# condition_2_Feedr       9.200591e+03
# condition_2_Norm        2.013993e+02
# condition_2_PosA        1.368732e+05
# condition_2_PosN       -3.466409e+04
# condition_2_RRNn        5.387747e+03
# dtype: float64

# %% [markdown]
# # Scoring and evaluating the model

# %%
# scoring

print(f'The training score is: {lr.score(X_train, y_train)}')
print(f'The testing score is: {lr.score(X_test, y_test)}')
print(f'The cross validation score is: {cross_val_score(lr, X_train, y_train, cv=5).mean()}')

# I think this is pretty good
# better than model 1
# Out:
# The training score is: 0.603420733838105
# The testing score is: 0.578512384225169
# The cross validation score is: 0.5500994675452218

# %%
# generate the predicted values
y_preds = lr.predict(X)

# %%
# Plot the model
plt.figure(figsize=(12,9))

# Generate a scatterplot of predicted values versus actual values.
plt.scatter(y_preds, y, s=5, color='skyblue', alpha = 0.5)

# Plot a line.
plt.plot([0, np.max(y)],
         [0, np.max(y)],
         color = 'black')

# Tweak title and axis labels.
plt.xlabel("Predicted Values: $\hat{y}$", fontsize = 20)
plt.ylabel("Actual Values: $y$", fontsize = 20)
plt.title('Predicted Values vs. Actual Values', fontsize = 24);

# looks like we might want to take the log

# %%
lr.predict(test_mod_3)
# Out:
# array([132634.83960044, 144199.38848315, 188619.71433876, 132634.83960044,
#        149842.33311551, 112188.88888889, 132634.83960044, 193203.75438778,
#        226327.99524723, 167310.37906489, 196715.93241823, 122056.42747504,
#        149842.33311551, 183894.74508689, 125646.54520952, 123967.27911583,
#        132634.83960044, 137322.98389955, 189790.86832692, 119279.13481672,
#        144199.38848315, 131378.20115182, 196715.93241823, 221875.        ,
#        132634.83960044, 242046.19230769, 188619.71433876, 193203.75438778,
#        242046.19230769, 188619.71433876, 314381.65517241, 189790.86832692,
#        149842.33311551, 149842.33311551, 185469.70019027, 187408.69855508,
#        242046.19230769, 149842.33311551, 137322.98389955, 143034.73482535,
#        226327.99524723, 347428.63110489, 122056.42747504, 193203.75438778,
#        112825.35787819, 203420.54987768, 193203.75438778, 140980.        ,
#        167310.37906489, 149842.33311551, 182526.41338896, 193203.75438778,
#        196715.93241823, 314381.65517241, 209053.81266866, 188666.66666667,
#        140980.        , 322860.01621859, 193203.75438778, 222474.94860038,
#        149842.33311551, 122056.42747504, 188619.71433876, 115469.1101818 ,
#        188619.71433876, 139088.42620819, 139088.42620819, 193501.99950488,
#        198290.88752161, 137021.14578417, 149842.33311551, 314381.65517241,
#        144199.38848315, 149842.33311551, 322860.01621859, 226327.99524723,
#        238239.42273302, 132634.83960044, 137322.98389955, 196715.93241823,
#        221875.        , 144199.38848315, 314381.65517241, 132634.83960044,
#        226327.99524723, 242046.19230769, 213506.80791589, 149842.33311551,
#        167310.37906489, 149842.33311551, 185143.2       , 149842.33311551,
#        193203.75438778, 322860.01621859, 185469.70019027, 123217.44938737,
#        347428.63110489, 149842.33311551, 193203.75438778, 149842.33311551,
#        182526.41338896, 322860.01621859, 221875.        , 137322.98389955,
#        193203.75438778, 182526.41338896, 189790.86832692, 226327.99524723,
#        140980.        , 193203.75438778, 180752.26006356, 169705.22605763,
#        149842.33311551, 149842.33311551, 137322.98389955, 132634.83960044,
#        347428.63110489, 112188.88888889, 193203.75438778, 167310.37906489,
#        322860.01621859, 136406.35307626, 100093.75      , 149842.33311551,
#        183894.74508689, 193203.75438778, 242046.19230769, 347428.63110489,
#        167310.37906489, 221875.        , 188619.71433876, 347428.63110489,
#        193203.75438778, 241747.57478349, 149842.33311551, 131378.20115182,
#        149842.33311551, 149842.33311551])

# %%
# let's submit this to kaggle

# this will go in the sale price column 
y_preds_test = lr.predict(test_mod_3)

submission = pd.DataFrame(y_preds_test, columns = ['SalePrice'])
submission['Id'] = test['id']

# %%
submission.shape
# Out:
# (878, 2)

# %%
submission.to_csv('../datasets/submissions/sub_3.csv', index = False)

# %%
# baseline model should be the mean of y
# look at april 2 notebook

# check the scores of the model with the mean
sub = pd.read_csv('../datasets/submissions/sub_3.csv')

# %%
sub.shape
# Out:
# (878, 2)

# %% [markdown]
# # Kaggle Score

# %% [markdown]
#  not yet submitted

# %% [markdown]
# # Logistic regression

# %% [markdown]
# Logistic regression straight up won't work. You don't actually have binary categories, you have "yes" and "no" as to whether the data is in a category of a categorical column.

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# importing originial train, test data

Z = pd.read_csv('../datasets/train_clean_no_dum.csv')

Y = pd.read_csv('../datasets/test_clean_no_dum.csv')

# %%
- MS Zoning
- Neighborhood
- Condition 1
- Condition 2

# %%
features2 = ['ms_zoning', 'neighborhood', 'condition_1', 'condition_2','saleprice']

# %%
Z = Z[features2]

# %%
Y = Y[features2]

# %%
sns.pairplot(Z, y_vars=features2, x_vars=['saleprice'])

# %%
saleprice = y

# %%
plt.hist(y, bins = 100)
plt.title('Sale Price Histogram');
